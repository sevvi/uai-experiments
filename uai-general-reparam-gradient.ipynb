# %%
# %matplotlib inline
from __future__ import print_function
import argparse, gzip, cPickle, sys, time, itertools

import autograd.numpy as np
import autograd.numpy.random as npr
import autograd.scipy.stats.norm as norm
import autograd.scipy.stats.dirichlet as dirichlet
from autograd.scipy.misc import logsumexp
from autograd.util import flatten_func, flatten
from autograd import grad, primitive
from autograd.numpy.numpy_grads import unbroadcast

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
from sklearn import mixture

from  autograd.scipy.special import gammaln, digamma, gamma
from scipy import linalg
from scipy import stats, integrate

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.animation as animation
import pandas as pd
import six

color_names = ["maroon",               
               "gold",
               "royal blue"]
colors = sns.xkcd_palette(color_names)
sns.set_style("white")


class Adam(object):
    def __init__(self, dparam, learning_rate=0.001, b1=0.9, b2=0.999, eps=10**-8,
                         decay_rate = 0.9, decay_steps = 100):                    
        self.b1 = b1;
        self.b2 = b2;
        self.eps = eps
        self.learning_rate = learning_rate        
        self.m = np.zeros(dparam)
        self.v = np.zeros(dparam)
        self.i = 0
        self.decay_rate = decay_rate
        self.decay_steps = decay_steps
    
    def step(self, gradients):        
        self.i = self.i+1
        step_size = self.learning_rate * self.decay_rate**(self.i/self.decay_steps)
        self.m = (1 - self.b1) * gradients + self.b1 * self.m
        self.v = (1 - self.b2) * (gradients**2) + self.b2 * self.v
        mhat = self.m / (1 - self.b1**(self.i))
        vhat = self.v / (1 - self.b2**(self.i))        
        step = step_size*mhat/(np.sqrt(vhat) + self.eps)        
        return step

    
@primitive
def softplus(x):
    return np.log(1. + np.exp(x))

softplus.defvjp(lambda g, ans, vs, gvs, x: unbroadcast(vs, gvs, g * 1./(1. + np.exp(-x))))

def jacobian_softplus(x):
    return 1./(1. + np.exp(-x))

@primitive
def gamma_logpdf(x, alpha = 1., beta = 1.):
    return  (alpha*np.log(beta) + (alpha - 1)*np.log(x) - x*beta - gammaln(alpha))

gamma_logpdf.defvjp(lambda g, ans, vs, gvs, x, alpha=1.0, beta=1.0: unbroadcast(vs, gvs, g * ((alpha-1)/x - beta)))
gamma_logpdf.defvjp(lambda g, ans, vs, gvs, x, alpha=1.0, beta=1.0: unbroadcast(vs, gvs,  g * (np.log(beta) + np.log(x) - digamma(alpha))), argnum=1)
gamma_logpdf.defvjp(lambda g, ans, vs, gvs, x, alpha=1.0, beta=1.0: unbroadcast(vs, gvs,  g * (alpha/beta - x)), argnum=2)

# %%
class Normal(object):
    def __init__(self, data, scale = 1.):
        self.data = data     
        self.scale = scale
        self.N = data.shape[0]
        self.D = data.shape[1]
    
    def p_log_prob(self, idx, z):
        x = self.data
        mu, tau = z['mu'], softplus(z['tau'])
        log_prior = 0.
        log_prior = np.sum(gamma_logpdf(tau, 1e-3, 1e-3)) + np.sum(np.log(jacobian_softplus(z['tau'])))
        log_prior += np.sum(norm.logpdf(mu, 0., 1/np.sqrt(tau)))        
        log_lik = np.sum(norm.logpdf(x, mu, 1/np.sqrt(tau)))
        return self.scale * log_lik + log_prior
    
    def q_log_prob(self, params, z):
        q_mean = np.sum(norm.logpdf(z['mu'], params['mu']['mean'], np.exp(params['mu']['sigma'])))
        q_sigma = np.sum(norm.logpdf(z['tau'], params['tau']['mean'], np.exp(params['tau']['sigma'])))        
        return q_mean + q_sigma
      
    def q_log_prob_sep(self, params, z):
        q_mean = norm.logpdf(z['mu'], params['mu']['mean'], np.exp(params['mu']['sigma']))
        q_sigma = norm.logpdf(z['tau'], params['tau']['mean'], np.exp(params['tau']['sigma']))
        return np.concatenate([q_mean, q_sigma])
    
    def sample_q(self, params):
        sample = {}
        eps = {}        
        eps['mu'] = npr.randn(len(params['mu']['mean']))
        eps['tau'] = npr.randn(len(params['tau']['mean']))        
        q_mu_s = np.exp(params['mu']['sigma']) * eps['mu'] + params['mu']['mean'] 
        q_tau_s = np.exp(params['tau']['sigma']) * eps['tau'] + params['tau']['mean'] 
        sample['mu'] = q_mu_s        
        sample['tau'] = q_tau_s
        return (sample, eps)
        
    def grad_p(self, dp_log_prob, eps, params):        
        dp_log_prob_ = {'mu': {}, 'tau': {}}
        
        dp_log_prob_['mu']['mean'] = dp_log_prob['mu']
        dp_log_prob_['mu']['sigma'] = dp_log_prob['mu']*eps['mu']*np.exp(params['mu']['sigma']) + 1
        
        dp_log_prob_['tau']['mean'] = dp_log_prob['tau']
        dp_log_prob_['tau']['sigma'] = dp_log_prob['tau']*eps['tau']*np.exp(params['tau']['sigma']) + 1                
        return dp_log_prob_
        
    def calc_eps(self, z, params):
        sample = {}
        eps = {}                
        eps['mu']  = (z['mu'] - params['mu']['mean']) / np.exp(params['mu']['sigma'])  
        eps['tau']  = (z['tau'] - params['tau']['mean']) / np.exp(params['tau']['sigma'])          
        return eps

# %%
class Inference(object):      
    def __init__(self, model, params):
        self.model = model
        self.params = params

    def run(self, epochs, batch_size, samples, learning_rate, algorithm = 'SGD', optimizer = 'adam'):
        self.epochs = epochs
        self.batches = self.model.N/batch_size
        self.batch_size = batch_size
        self.samples = samples
        self.learning_rate = learning_rate
        
        fparams, unflatten = flatten(self.params)
        self.D =len(fparams)

        self.loss = 0.
        self.F = np.zeros(self.epochs * self.batches)
        self.time = np.zeros(self.epochs * self.batches)
        self.n = 1
        adam = Adam(self.D, learning_rate = learning_rate)        
        f = 0
        
        grad_p_log_prob = grad(model.p_log_prob, argnum = 1)
        grad_q_log_prob = grad(model.q_log_prob, argnum = 1)
        p = []
        c = []
        
        if algorithm == 'SGD':
            for e in range(self.epochs):
                for b in range(self.batches): 
                    start = time.clock()
                    losses = 0.
                    d_elbo = 0.
                    idx = 0
                    d_elbo = 0.

                    params = unflatten(fparams)                
                    for s in range(self.samples):
                        z, eps = model.sample_q(params)
                        p_log_prob = model.p_log_prob(idx, z)
                        g,_ =  flatten(model.grad_p(grad_p_log_prob(idx, z), eps, params))
                        d_elbo += g
                        q_log_prob = model.q_log_prob(params, z)                                         
                        losses +=  (p_log_prob - q_log_prob)
                    loss = losses/self.samples
                    d_elbo /= self.samples
                    step = adam.step(d_elbo)
                    fparams += step                        
                    self.F[f] =  -loss                
                    stop = time.clock()
                    p.append(unflatten(np.copy(fparams)))

                    self.time[f] = stop - start
                    f+=1
                if e % 10 == 0:
                    pstate = 'Epoch = ' + "{0:0=3d}".format(e) + ': Loss = {0:.3f}'.format(self.F[f-1])
                    print (pstate, end = '\r')
                    sys.stdout.flush()    
                    
                      
        if algorithm == 'iSGD':
            n = 1.  
            z_old = [0.] * self.samples
            grad_p_old = [0.] * self.samples
            q_log_prob_old = [0.] * self.samples
            p_log_prob_old = [0.] * self.samples
            
            for e in range(self.epochs):
                for b in range(self.batches): 
                    start = time.clock()
                    losses = 0.
                    d_elbo = 0.
                    idx = 0
                    d_elbo = 0.
                    params = unflatten(fparams)                
                    if n > .9:
                        for s in range(self.samples):
                            z, eps = model.sample_q(params)
                            p_log_prob = model.p_log_prob(idx, z)
                            q_log_prob = model.q_log_prob_sep(params, z)                                                                                          
                            grad_p = grad_p_log_prob(idx, z)
                            g,_ =  flatten(model.grad_p(grad_p, eps, params))
                            d_elbo += g                            
                            losses +=  (p_log_prob - np.sum(q_log_prob))
                            c.append("s")                            
                            z_old[s] = z
                            grad_p_old[s] = grad_p
                            q_log_prob_old[s] = q_log_prob
                            p_log_prob_old[s] = p_log_prob                    
                        loss = losses/self.samples
                        d_elbo /= self.samples
                    else:
                        for s in range(self.samples):
                            eps_ = model.calc_eps(z_old[s], params)
                            q_log_prob = model.q_log_prob_sep(params, z_old[s])                                      
                            w = np.exp(q_log_prob - q_log_prob_old[s]) 
                            gw, unflatten_gw = flatten(grad_p_old[s])
                            g,_ =  flatten(model.grad_p(unflatten_gw(w*gw), eps_, params))                                                        
                            d_elbo += g                            
                            c.append("i")                            

                        d_elbo /= self.samples
                    n = npr.uniform()
                    step = adam.step(d_elbo)
                    fparams += step                        
                    self.F[f] =  -loss                
                    stop = time.clock()
                    p.append(unflatten(np.copy(fparams)))

                    self.time[f] = stop - start
                    f+=1                       
                if e % 10 == 0:
                    pstate = 'Epoch = ' + "{0:0=3d}".format(e) + ': Loss = {0:.3f}'.format(self.F[f-1])
                    print (pstate, end = '\r')
                    sys.stdout.flush()    
        self.params = unflatten(fparams)   
        return (p,c)

# %%
N = 1000
D = 100
batch_size = 1000
epochs = 10
samples = 1
learning_rate = 0.1
seed = 111
npr.seed(seed)    
data = 5 * npr.randn(N*D).reshape([N,D])
    
N = data.shape[0]
D = data.shape[1]
model = Normal(data)

npr.seed(seed)    
params = {}
params['mu'] = {'mean': npr.randn(D), 'sigma': npr.randn(D)}
params['tau'] = {'mean': npr.randn(D), 'sigma': npr.randn(D)}
inference = Inference(model, params)
inference.run(epochs, batch_size, samples, learning_rate, 'iSGD')
plt.plot(np.cumsum(inference.time), -inference.F, color = colors[0])

npr.seed(seed)    
params = {}
params['mu'] = {'mean': npr.randn(D), 'sigma': npr.randn(D)}
params['tau'] = {'mean': npr.randn(D), 'sigma': npr.randn(D)}
inference = Inference(model, params)
inference.run(epochs, batch_size, samples, learning_rate, 'SGD')
plt.plot(np.cumsum(inference.time), -inference.F, color = colors[1])
# Out:
# Epoch = 000: Loss = 1875730.113

# %%
def log_density(x):
    mu, sigma = x[0], softplus(x[1])
    sigma_density = gamma_logpdf(sigma, 1e-3, 1e-3) + np.log(jacobian_softplus(x[1]))
    mu_density = norm.logpdf(mu, 0, 1/np.sqrt(sigma))
    return sigma_density + mu_density

sns.set_style(style='white')
x = np.linspace(-3, 3, 101)
y = np.linspace(-3, 7, 101)
X, Y = np.meshgrid(x, y)
zs = np.array([np.exp(log_density(theta))
               for theta in zip(np.ravel(X), np.ravel(Y))])        
Z = zs.reshape(X.shape)
#f, (ax1, ax2) = plt.subplots(2,1,figsize=(30,50))
plt.contour(X, Y, Z, colors = 'k', alpha = .5)

N = 1000
D = 1
batch_size = 1000
epochs = 500
samples = 1
learning_rate = 0.1
seed = 111
npr.seed(seed)    
data =  npr.randn(N*D).reshape([N,D])
    
N = data.shape[0]
D = data.shape[1]
model = Normal(data)

npr.seed(seed)    
params = {}
params['mu'] = {'mean': 3 * np.ones(D), 'sigma': npr.randn(D)}
params['tau'] = {'mean': 4 * np.ones(D), 'sigma': npr.randn(D)}
inference = Inference(model, params)
p,c = inference.run(epochs, batch_size, samples, learning_rate, 'iSGD')

col = {'s': colors[0], 'i': colors[1]}
area = {'s': 5, 'i': 2}
shape = {'s': 'd', 'i': '.'}
plt.scatter([t['mu']['mean'] for t in p], softplus([t['tau']['mean'] for t in p]), 
              s = [area[t] for t in c], alpha=1, color = [col[t]for t in  c],
           marker = 'd')             


npr.seed(seed)    
params = {}
params['mu'] = {'mean': -3 * np.ones(D), 'sigma': npr.randn(D)}
params['tau'] = {'mean': 4*np.ones(D), 'sigma': npr.randn(D)}
inference = Inference(model, params)
p,c = inference.run(epochs, batch_size, samples, learning_rate, 'SGD')
plt.scatter([t['mu']['mean'] for t in p], softplus([t['tau']['mean'] for t in p]), 
              s = 2, alpha=1, color = colors[2])     


plt.ylabel(r'$\tau$', fontsize = 15)
plt.xlabel(r'$\mu$', fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.savefig('/home/sakaya/MUPI/papers/uai17importance/normal-illustration.png', dpi=300, bbox_inches= 'tight')
# Out:
# Epoch = 490: Loss = 1441.0115

# %%
inference.params
# Out:
# {'mu': {'mean': array([-0.09145948]), 'sigma': array([-1.91208014])},
#  'tau': {'mean': array([-3.29480589]), 'sigma': array([-2.11863818])}}

# %%
p
# Out:
# [{'mu': {'mean': array([ 2.5]), 'sigma': array([-1.63383833])},
#   'tau': {'mean': array([ 0.5]), 'sigma': array([ 0.88431919])}},
#  {'mu': {'mean': array([ 2.07055744]), 'sigma': array([-1.93073512])},
#   'tau': {'mean': array([ 0.04262701]), 'sigma': array([ 1.38344993])}},
#  {'mu': {'mean': array([ 1.69874617]), 'sigma': array([-2.15923974])},
#   'tau': {'mean': array([-0.36826811]), 'sigma': array([ 1.86574366])}},
#  {'mu': {'mean': array([ 1.39413617]), 'sigma': array([-2.34623222])},
#   'tau': {'mean': array([-0.6932331]), 'sigma': array([ 2.11580707])}},
#  {'mu': {'mean': array([ 1.1362499]), 'sigma': array([-2.50413899])},
#   'tau': {'mean': array([-0.9580898]), 'sigma': array([ 2.26176857])}},
#  {'mu': {'mean': array([ 0.80268931]), 'sigma': array([-2.50811115])},
#   'tau': {'mean': array([-1.30443324]), 'sigma': array([ 2.01483606])}},
#  {'mu': {'mean': array([ 0.50816691]), 'sigma': array([-2.51027756])},
#   'tau': {'mean': array([-1.62145261]), 'sigma': array([ 1.80112071])}},
#  {'mu': {'mean': array([ 0.22518203]), 'sigma': array([-2.51629458])},
#   'tau': {'mean': array([-1.98151796]), 'sigma': array([ 1.56091555])}},
#  {'mu': {'mean': array([-0.03187975]), 'sigma': array([-2.52414649])},
#   'tau': {'mean': array([-2.34616208]), 'sigma': array([ 1.33183143])}},
#  {'mu': {'mean': array([-0.26131085]), 'sigma': array([-2.53102126])},
#   'tau': {'mean': array([-2.67603732]), 'sigma': array([ 1.12762088])}},
#  {'mu': {'mean': array([-0.46653422]), 'sigma': array([-2.53717864])},
#   'tau': {'mean': array([-2.97283375]), 'sigma': array([ 0.94469493])}},
#  {'mu': {'mean': array([-0.6464051]), 'sigma': array([-2.54168562])},
#   'tau': {'mean': array([-3.28066025]), 'sigma': array([ 0.75830761])}},
#  {'mu': {'mean': array([-0.80639012]), 'sigma': array([-2.54684263])},
#   'tau': {'mean': array([-3.5665308]), 'sigma': array([ 0.58843985])}},
#  {'mu': {'mean': array([-0.92380742]), 'sigma': array([-2.55413871])},
#   'tau': {'mean': array([-3.89607878]), 'sigma': array([ 0.36187861])}},
#  {'mu': {'mean': array([-1.02988803]), 'sigma': array([-2.56051535])},
#   'tau': {'mean': array([-4.19004186]), 'sigma': array([ 0.15601532])}},
#  {'mu': {'mean': array([-1.12595438]), 'sigma': array([-2.56618258])},
#   'tau': {'mean': array([-4.45132587]), 'sigma': array([-0.03262218])}},
#  {'mu': {'mean': array([-1.21279167]), 'sigma': array([-2.57115241])},
#   'tau': {'mean': array([-4.68439591]), 'sigma': array([-0.20388531])}},
#  {'mu': {'mean': array([-1.29134037]), 'sigma': array([-2.57547627])},
#   'tau': {'mean': array([-4.89188416]), 'sigma': array([-0.35943028])}},
#  {'mu': {'mean': array([-1.36254522]), 'sigma': array([-2.57937481])},
#   'tau': {'mean': array([-5.07555163]), 'sigma': array([-0.50137166])}},
#  {'mu': {'mean': array([-1.42699116]), 'sigma': array([-2.58291401])},
#   'tau': {'mean': array([-5.23804061]), 'sigma': array([-0.63034844])}},
#  {'mu': {'mean': array([-1.48542717]), 'sigma': array([-2.58601642])},
#   'tau': {'mean': array([-5.38091647]), 'sigma': array([-0.74786862])}},
#  {'mu': {'mean': array([-1.53807162]), 'sigma': array([-2.58875813])},
#   'tau': {'mean': array([-5.50707412]), 'sigma': array([-0.85406916])}},
#  {'mu': {'mean': array([-1.58569752]), 'sigma': array([-2.59103941])},
#   'tau': {'mean': array([-5.61720317]), 'sigma': array([-0.9502747])}},
#  {'mu': {'mean': array([-1.62897144]), 'sigma': array([-2.59290429])},
#   'tau': {'mean': array([-5.71199897]), 'sigma': array([-1.03846888])}},
#  {'mu': {'mean': array([-1.66822234]), 'sigma': array([-2.59442734])},
#   'tau': {'mean': array([-5.79296203]), 'sigma': array([-1.1188199])}},
#  {'mu': {'mean': array([-1.70383651]), 'sigma': array([-2.59554566])},
#   'tau': {'mean': array([-5.86122221]), 'sigma': array([-1.19204002])}},
#  {'mu': {'mean': array([-1.73608585]), 'sigma': array([-2.59647499])},
#   'tau': {'mean': array([-5.91793085]), 'sigma': array([-1.25855553])}},
#  {'mu': {'mean': array([-1.76525237]), 'sigma': array([-2.59717358])},
#   'tau': {'mean': array([-5.96411003]), 'sigma': array([-1.31878511])}},
#  {'mu': {'mean': array([-1.79169435]), 'sigma': array([-2.59766443])},
#   'tau': {'mean': array([-6.00036623]), 'sigma': array([-1.3738614])}},
#  {'mu': {'mean': array([-1.81569647]), 'sigma': array([-2.59796873])},
#   'tau': {'mean': array([-6.02737668]), 'sigma': array([-1.42475455])}},
#  {'mu': {'mean': array([-1.83742333]), 'sigma': array([-2.59810787])},
#   'tau': {'mean': array([-6.04603083]), 'sigma': array([-1.47124896])}},
#  {'mu': {'mean': array([-1.85704806]), 'sigma': array([-2.598067])},
#   'tau': {'mean': array([-6.0570794]), 'sigma': array([-1.5134798])}},
#  {'mu': {'mean': array([-1.87478047]), 'sigma': array([-2.59785201])},
#   'tau': {'mean': array([-6.0610533]), 'sigma': array([-1.55202596])}},
#  {'mu': {'mean': array([-1.89072495]), 'sigma': array([-2.59757311])},
#   'tau': {'mean': array([-6.05865221]), 'sigma': array([-1.58685285])}},
#  {'mu': {'mean': array([-1.90503529]), 'sigma': array([-2.59710431])},
#   'tau': {'mean': array([-6.05041042]), 'sigma': array([-1.61819038])}},
#  {'mu': {'mean': array([-1.91792199]), 'sigma': array([-2.59648141])},
#   'tau': {'mean': array([-6.03658227]), 'sigma': array([-1.64688159])}},
#  {'mu': {'mean': array([-1.92949395]), 'sigma': array([-2.59575312])},
#   'tau': {'mean': array([-6.01762595]), 'sigma': array([-1.67309837])}},
#  {'mu': {'mean': array([-1.93983037]), 'sigma': array([-2.59490149])},
#   'tau': {'mean': array([-5.99403112]), 'sigma': array([-1.69680588])}},
#  {'mu': {'mean': array([-1.94907865]), 'sigma': array([-2.59394053])},
#   'tau': {'mean': array([-5.96603322]), 'sigma': array([-1.71857521])}},
#  {'mu': {'mean': array([-1.95727284]), 'sigma': array([-2.59291083])},
#   'tau': {'mean': array([-5.9341125]), 'sigma': array([-1.73821296])}},
#  {'mu': {'mean': array([-1.96452279]), 'sigma': array([-2.59175628])},
#   'tau': {'mean': array([-5.8985187]), 'sigma': array([-1.75602816])}},
#  {'mu': {'mean': array([-1.97093597]), 'sigma': array([-2.59044907])},
#   'tau': {'mean': array([-5.85945623]), 'sigma': array([-1.77238422])}},
#  {'mu': {'mean': array([-1.97651225]), 'sigma': array([-2.58905751])},
#   'tau': {'mean': array([-5.81734949]), 'sigma': array([-1.78706292])}},
#  {'mu': {'mean': array([-1.98138011]), 'sigma': array([-2.58763322])},
#   'tau': {'mean': array([-5.77224741]), 'sigma': array([-1.80066316])}},
#  {'mu': {'mean': array([-1.98543646]), 'sigma': array([-2.58623117])},
#   'tau': {'mean': array([-5.72477901]), 'sigma': array([-1.81253951])}},
#  {'mu': {'mean': array([-1.98880998]), 'sigma': array([-2.58498921])},
#   'tau': {'mean': array([-5.67491052]), 'sigma': array([-1.82322708])}},
#  {'mu': {'mean': array([-1.99147009]), 'sigma': array([-2.58371226])},
#   'tau': {'mean': array([-5.62307088]), 'sigma': array([-1.8324688])}},
#  {'mu': {'mean': array([-1.99357682]), 'sigma': array([-2.58246776])},
#   'tau': {'mean': array([-5.56910296]), 'sigma': array([-1.84089704])}},
#  {'mu': {'mean': array([-1.99517759]), 'sigma': array([-2.58130703])},
#   'tau': {'mean': array([-5.51312737]), 'sigma': array([-1.84869855])}},
#  {'mu': {'mean': array([-1.99628742]), 'sigma': array([-2.58004583])},
#   'tau': {'mean': array([-5.4553793]), 'sigma': array([-1.85579334])}},
#  {'mu': {'mean': array([-1.99698809]), 'sigma': array([-2.57863492])},
#   'tau': {'mean': array([-5.39586966]), 'sigma': array([-1.86248511])}},
#  {'mu': {'mean': array([-1.99717364]), 'sigma': array([-2.5773583])},
#   'tau': {'mean': array([-5.33500814]), 'sigma': array([-1.868461])}},
#  {'mu': {'mean': array([-1.99692689]), 'sigma': array([-2.57622225])},
#   'tau': {'mean': array([-5.27275486]), 'sigma': array([-1.87402657])}},
#  {'mu': {'mean': array([-1.99630078]), 'sigma': array([-2.57501128])},
#   'tau': {'mean': array([-5.20918079]), 'sigma': array([-1.87929268])}},
#  {'mu': {'mean': array([-1.99515504]), 'sigma': array([-2.57353369])},
#   'tau': {'mean': array([-5.14485013]), 'sigma': array([-1.88380078])}},
#  {'mu': {'mean': array([-1.99362465]), 'sigma': array([-2.57194984])},
#   'tau': {'mean': array([-5.07950587]), 'sigma': array([-1.88799956])}},
#  {'mu': {'mean': array([-1.99169599]), 'sigma': array([-2.5702216])},
#   'tau': {'mean': array([-5.0133183]), 'sigma': array([-1.89186862])}},
#  {'mu': {'mean': array([-1.989195]), 'sigma': array([-2.56853874])},
#   'tau': {'mean': array([-4.94681411]), 'sigma': array([-1.89512605])}},
#  {'mu': {'mean': array([-1.98619443]), 'sigma': array([-2.56691873])},
#   'tau': {'mean': array([-4.87990364]), 'sigma': array([-1.89796996])}},
#  {'mu': {'mean': array([-1.98260495]), 'sigma': array([-2.56596572])},
#   'tau': {'mean': array([-4.81279315]), 'sigma': array([-1.90041375])}},
#  {'mu': {'mean': array([-1.97854762]), 'sigma': array([-2.56516099])},
#   'tau': {'mean': array([-4.74535881]), 'sigma': array([-1.90262732])}},
#  {'mu': {'mean': array([-1.9740755]), 'sigma': array([-2.56389128])},
#   'tau': {'mean': array([-4.67769052]), 'sigma': array([-1.90462308])}},
#  {'mu': {'mean': array([-1.96920625]), 'sigma': array([-2.56247368])},
#   'tau': {'mean': array([-4.60973679]), 'sigma': array([-1.90654838])}},
#  {'mu': {'mean': array([-1.96377156]), 'sigma': array([-2.56099709])},
#   'tau': {'mean': array([-4.54199034]), 'sigma': array([-1.90821424])}},
#  {'mu': {'mean': array([-1.95766017]), 'sigma': array([-2.55988622])},
#   'tau': {'mean': array([-4.47471312]), 'sigma': array([-1.9096034])}},
#  {'mu': {'mean': array([-1.95081918]), 'sigma': array([-2.55831466])},
#   'tau': {'mean': array([-4.40830428]), 'sigma': array([-1.91063335])}},
#  {'mu': {'mean': array([-1.94368157]), 'sigma': array([-2.55671501])},
#   'tau': {'mean': array([-4.34156452]), 'sigma': array([-1.91190758])}},
#  {'mu': {'mean': array([-1.93604208]), 'sigma': array([-2.5547901])},
#   'tau': {'mean': array([-4.27516817]), 'sigma': array([-1.91313326])}},
#  {'mu': {'mean': array([-1.92790112]), 'sigma': array([-2.55309713])},
#   'tau': {'mean': array([-4.20902579]), 'sigma': array([-1.91442399])}},
#  {'mu': {'mean': array([-1.91897179]), 'sigma': array([-2.55212294])},
#   'tau': {'mean': array([-4.14383952]), 'sigma': array([-1.91559185])}},
#  {'mu': {'mean': array([-1.90937119]), 'sigma': array([-2.55011421])},
#   'tau': {'mean': array([-4.07979402]), 'sigma': array([-1.91660182])}},
#  {'mu': {'mean': array([-1.89896081]), 'sigma': array([-2.54750081])},
#   'tau': {'mean': array([-4.01718315]), 'sigma': array([-1.91744701])}},
#  {'mu': {'mean': array([-1.88811063]), 'sigma': array([-2.54550367])},
#   'tau': {'mean': array([-3.95473926]), 'sigma': array([-1.91855341])}},
#  {'mu': {'mean': array([-1.87598792]), 'sigma': array([-2.54355114])},
#   'tau': {'mean': array([-3.89489565]), 'sigma': array([-1.91942042])}},
#  {'mu': {'mean': array([-1.86299246]), 'sigma': array([-2.54221518])},
#   'tau': {'mean': array([-3.83647476]), 'sigma': array([-1.92023804])}},
#  {'mu': {'mean': array([-1.84916364]), 'sigma': array([-2.54092804])},
#   'tau': {'mean': array([-3.77955955]), 'sigma': array([-1.92101283])}},
#  {'mu': {'mean': array([-1.8343762]), 'sigma': array([-2.53940437])},
#   'tau': {'mean': array([-3.72461976]), 'sigma': array([-1.92170159])}},
#  {'mu': {'mean': array([-1.8192101]), 'sigma': array([-2.53822628])},
#   'tau': {'mean': array([-3.66994419]), 'sigma': array([-1.9226652])}},
#  {'mu': {'mean': array([-1.80291554]), 'sigma': array([-2.53673945])},
#   'tau': {'mean': array([-3.6178406]), 'sigma': array([-1.9235149])}},
#  {'mu': {'mean': array([-1.78449418]), 'sigma': array([-2.53465961])},
#   'tau': {'mean': array([-3.57122303]), 'sigma': array([-1.92432537])}},
#  {'mu': {'mean': array([-1.76509822]), 'sigma': array([-2.53130425])},
#   'tau': {'mean': array([-3.52718984]), 'sigma': array([-1.92503312])}},
#  {'mu': {'mean': array([-1.74482231]), 'sigma': array([-2.52842356])},
#   'tau': {'mean': array([-3.48498804]), 'sigma': array([-1.92570299])}},
#  {'mu': {'mean': array([-1.72288805]), 'sigma': array([-2.52806792])},
#   'tau': {'mean': array([-3.4463367]), 'sigma': array([-1.92629569])}},
#  {'mu': {'mean': array([-1.69959569]), 'sigma': array([-2.52754923])},
#   'tau': {'mean': array([-3.41122835]), 'sigma': array([-1.92682533])}},
#  {'mu': {'mean': array([-1.67581723]), 'sigma': array([-2.52599864])},
#   'tau': {'mean': array([-3.3775266]), 'sigma': array([-1.92734323])}},
#  {'mu': {'mean': array([-1.65148719]), 'sigma': array([-2.52310592])},
#   'tau': {'mean': array([-3.34563477]), 'sigma': array([-1.92782731])}},
#  {'mu': {'mean': array([-1.62612768]), 'sigma': array([-2.52115977])},
#   'tau': {'mean': array([-3.31624006]), 'sigma': array([-1.92826328])}},
#  {'mu': {'mean': array([-1.59994189]), 'sigma': array([-2.51917247])},
#   'tau': {'mean': array([-3.28916946]), 'sigma': array([-1.92865659])}},
#  {'mu': {'mean': array([-1.57173255]), 'sigma': array([-2.5168034])},
#   'tau': {'mean': array([-3.26829917]), 'sigma': array([-1.92924712])}},
#  {'mu': {'mean': array([-1.54115237]), 'sigma': array([-2.514806])},
#   'tau': {'mean': array([-3.25457519]), 'sigma': array([-1.93021142])}},
#  {'mu': {'mean': array([-1.50990021]), 'sigma': array([-2.51170653])},
#   'tau': {'mean': array([-3.24353216]), 'sigma': array([-1.9311091])}},
#  {'mu': {'mean': array([-1.47799622]), 'sigma': array([-2.5091699])},
#   'tau': {'mean': array([-3.23453418]), 'sigma': array([-1.93192693])}},
#  {'mu': {'mean': array([-1.44576155]), 'sigma': array([-2.50617478])},
#   'tau': {'mean': array([-3.22713808]), 'sigma': array([-1.93266645])}},
#  {'mu': {'mean': array([-1.41260331]), 'sigma': array([-2.50189879])},
#   'tau': {'mean': array([-3.22388965]), 'sigma': array([-1.93351242])}},
#  {'mu': {'mean': array([-1.37931607]), 'sigma': array([-2.49850983])},
#   'tau': {'mean': array([-3.22120259]), 'sigma': array([-1.93427151])}},
#  {'mu': {'mean': array([-1.34590117]), 'sigma': array([-2.49551942])},
#   'tau': {'mean': array([-3.21943874]), 'sigma': array([-1.93495481])}},
#  {'mu': {'mean': array([-1.3126009]), 'sigma': array([-2.49025736])},
#   'tau': {'mean': array([-3.21958414]), 'sigma': array([-1.93561293])}},
#  {'mu': {'mean': array([-1.27894515]), 'sigma': array([-2.48641901])},
#   'tau': {'mean': array([-3.22116541]), 'sigma': array([-1.93622672])}},
#  {'mu': {'mean': array([-1.24502804]), 'sigma': array([-2.4843781])},
#   'tau': {'mean': array([-3.22377367]), 'sigma': array([-1.9367904])}},
#  {'mu': {'mean': array([-1.21476568]), 'sigma': array([-2.48470057])},
#   'tau': {'mean': array([-3.22499016]), 'sigma': array([-1.93727533])}},
#  {'mu': {'mean': array([-1.18388424]), 'sigma': array([-2.48712713])},
#   'tau': {'mean': array([-3.22853712]), 'sigma': array([-1.93780412])}},
#  {'mu': {'mean': array([-1.15383822]), 'sigma': array([-2.48872803])},
#   'tau': {'mean': array([-3.23062474]), 'sigma': array([-1.93831342])}},
#  {'mu': {'mean': array([-1.12471089]), 'sigma': array([-2.48938137])},
#   'tau': {'mean': array([-3.23107917]), 'sigma': array([-1.93882385])}},
#  {'mu': {'mean': array([-1.09560537]), 'sigma': array([-2.49049367])},
#   'tau': {'mean': array([-3.23256498]), 'sigma': array([-1.93929953])}},
#  {'mu': {'mean': array([-1.06682689]), 'sigma': array([-2.49259828])},
#   'tau': {'mean': array([-3.23344984]), 'sigma': array([-1.93973273])}},
#  {'mu': {'mean': array([-1.03784378]), 'sigma': array([-2.49503768])},
#   'tau': {'mean': array([-3.23661803]), 'sigma': array([-1.94022116])}},
#  {'mu': {'mean': array([-1.00956174]), 'sigma': array([-2.49645944])},
#   'tau': {'mean': array([-3.23939547]), 'sigma': array([-1.94065872])}},
#  {'mu': {'mean': array([-0.98232032]), 'sigma': array([-2.49718471])},
#   'tau': {'mean': array([-3.23988793]), 'sigma': array([-1.94114687])}},
#  {'mu': {'mean': array([-0.95595937]), 'sigma': array([-2.4967712])},
#   'tau': {'mean': array([-3.23950077]), 'sigma': array([-1.941598])}},
#  {'mu': {'mean': array([-0.92983696]), 'sigma': array([-2.49696617])},
#   'tau': {'mean': array([-3.23931169]), 'sigma': array([-1.94200186])}},
#  {'mu': {'mean': array([-0.90388136]), 'sigma': array([-2.49745697])},
#   'tau': {'mean': array([-3.24005136]), 'sigma': array([-1.94237928])}},
#  {'mu': {'mean': array([-0.87839916]), 'sigma': array([-2.49754925])},
#   'tau': {'mean': array([-3.24105829]), 'sigma': array([-1.94271886])}},
#  {'mu': {'mean': array([-0.85347626]), 'sigma': array([-2.49811854])},
#   'tau': {'mean': array([-3.24075667]), 'sigma': array([-1.94305349])}},
#  {'mu': {'mean': array([-0.82945972]), 'sigma': array([-2.4978898])},
#   'tau': {'mean': array([-3.23910691]), 'sigma': array([-1.94338969])}},
#  {'mu': {'mean': array([-0.8062244]), 'sigma': array([-2.49679895])},
#   'tau': {'mean': array([-3.23701505]), 'sigma': array([-1.94369489])}},
#  {'mu': {'mean': array([-0.78352277]), 'sigma': array([-2.49557854])},
#   'tau': {'mean': array([-3.23453284]), 'sigma': array([-1.94397257])}},
#  {'mu': {'mean': array([-0.76101696]), 'sigma': array([-2.49529322])},
#   'tau': {'mean': array([-3.23203166]), 'sigma': array([-1.94422038])}},
#  {'mu': {'mean': array([-0.73907566]), 'sigma': array([-2.49560038])},
#   'tau': {'mean': array([-3.22770809]), 'sigma': array([-1.94453659])}},
#  {'mu': {'mean': array([-0.71733272]), 'sigma': array([-2.49504898])},
#   'tau': {'mean': array([-3.22679893]), 'sigma': array([-1.94498529])}},
#  {'mu': {'mean': array([-0.69608187]), 'sigma': array([-2.49432261])},
#   'tau': {'mean': array([-3.22581166]), 'sigma': array([-1.94538666])}},
#  {'mu': {'mean': array([-0.67528518]), 'sigma': array([-2.49349813])},
#   'tau': {'mean': array([-3.22484419]), 'sigma': array([-1.94574483])}},
#  {'mu': {'mean': array([-0.6550664]), 'sigma': array([-2.49281804])},
#   'tau': {'mean': array([-3.22244745]), 'sigma': array([-1.94611377])}},
#  {'mu': {'mean': array([-0.63532811]), 'sigma': array([-2.49172])},
#   'tau': {'mean': array([-3.22081274]), 'sigma': array([-1.94644843])}},
#  {'mu': {'mean': array([-0.61565963]), 'sigma': array([-2.49154921])},
#   'tau': {'mean': array([-3.21969157]), 'sigma': array([-1.9467482])}},
#  {'mu': {'mean': array([-0.59623327]), 'sigma': array([-2.49245498])},
#   'tau': {'mean': array([-3.21749605]), 'sigma': array([-1.94704584])}},
#  {'mu': {'mean': array([-0.57784927]), 'sigma': array([-2.49243233])},
#   'tau': {'mean': array([-3.21403626]), 'sigma': array([-1.94735448])}},
#  {'mu': {'mean': array([-0.56026216]), 'sigma': array([-2.49149717])},
#   'tau': {'mean': array([-3.21145459]), 'sigma': array([-1.94763458])}},
#  {'mu': {'mean': array([-0.54319909]), 'sigma': array([-2.49031436])},
#   'tau': {'mean': array([-3.20847763]), 'sigma': array([-1.94789185])}},
#  {'mu': {'mean': array([-0.52621109]), 'sigma': array([-2.48900026])},
#   'tau': {'mean': array([-3.20868455]), 'sigma': array([-1.94826206])}},
#  {'mu': {'mean': array([-0.5096973]), 'sigma': array([-2.48768584])},
#   'tau': {'mean': array([-3.20790134]), 'sigma': array([-1.94861245])}},
#  {'mu': {'mean': array([-0.49369227]), 'sigma': array([-2.48623218])},
#   'tau': {'mean': array([-3.20639053]), 'sigma': array([-1.94893827])}},
#  {'mu': {'mean': array([-0.47793231]), 'sigma': array([-2.48549486])},
#   'tau': {'mean': array([-3.20341971]), 'sigma': array([-1.94928602])}},
#  {'mu': {'mean': array([-0.46246025]), 'sigma': array([-2.48481837])},
#   'tau': {'mean': array([-3.2008793]), 'sigma': array([-1.94959531])}},
#  {'mu': {'mean': array([-0.44728107]), 'sigma': array([-2.48411204])},
#   'tau': {'mean': array([-3.1991501]), 'sigma': array([-1.9498742])}},
#  {'mu': {'mean': array([-0.432477]), 'sigma': array([-2.48320747])},
#   'tau': {'mean': array([-3.19833167]), 'sigma': array([-1.95012932])}},
#  {'mu': {'mean': array([-0.41810628]), 'sigma': array([-2.48201821])},
#   'tau': {'mean': array([-3.19846444]), 'sigma': array([-1.95036635])}},
#  {'mu': {'mean': array([-0.40441969]), 'sigma': array([-2.48034545])},
#   'tau': {'mean': array([-3.19910194]), 'sigma': array([-1.95057925])}},
#  {'mu': {'mean': array([-0.39094566]), 'sigma': array([-2.4788205])},
#   'tau': {'mean': array([-3.20018591]), 'sigma': array([-1.95076981])}},
#  {'mu': {'mean': array([-0.37756156]), 'sigma': array([-2.47741669])},
#   'tau': {'mean': array([-3.20345848]), 'sigma': array([-1.9510218])}},
#  {'mu': {'mean': array([-0.36454913]), 'sigma': array([-2.47572535])},
#   'tau': {'mean': array([-3.20896136]), 'sigma': array([-1.95135158])}},
#  {'mu': {'mean': array([-0.35207258]), 'sigma': array([-2.47373467])},
#   'tau': {'mean': array([-3.21490065]), 'sigma': array([-1.95166124])}},
#  {'mu': {'mean': array([-0.34006203]), 'sigma': array([-2.47160169])},
#   'tau': {'mean': array([-3.22013135]), 'sigma': array([-1.95193602])}},
#  {'mu': {'mean': array([-0.32830285]), 'sigma': array([-2.4696489])},
#   'tau': {'mean': array([-3.22449635]), 'sigma': array([-1.95218084])}},
#  {'mu': {'mean': array([-0.3165046]), 'sigma': array([-2.46815351])},
#   'tau': {'mean': array([-3.23018818]), 'sigma': array([-1.95245436])}},
#  {'mu': {'mean': array([-0.30551801]), 'sigma': array([-2.46631942])},
#   'tau': {'mean': array([-3.23497354]), 'sigma': array([-1.95269683])}},
#  {'mu': {'mean': array([-0.29507384]), 'sigma': array([-2.46426421])},
#   'tau': {'mean': array([-3.23875669]), 'sigma': array([-1.95291299])}},
#  {'mu': {'mean': array([-0.28492258]), 'sigma': array([-2.46226345])},
#   'tau': {'mean': array([-3.24124171]), 'sigma': array([-1.95311368])}},
#  {'mu': {'mean': array([-0.27499944]), 'sigma': array([-2.46030699])},
#   'tau': {'mean': array([-3.24368333]), 'sigma': array([-1.95329173])}},
#  {'mu': {'mean': array([-0.26594226]), 'sigma': array([-2.45816291])},
#   'tau': {'mean': array([-3.24439861]), 'sigma': array([-1.95347826])}},
#  {'mu': {'mean': array([-0.25692505]), 'sigma': array([-2.45628453])},
#   'tau': {'mean': array([-3.24495825]), 'sigma': array([-1.95364093])}},
#  {'mu': {'mean': array([-0.24859238]), 'sigma': array([-2.45418272])},
#   'tau': {'mean': array([-3.24446682]), 'sigma': array([-1.953793])}},
#  {'mu': {'mean': array([-0.24067692]), 'sigma': array([-2.4519601])},
#   'tau': {'mean': array([-3.24148575]), 'sigma': array([-1.95403366])}},
#  {'mu': {'mean': array([-0.23314941]), 'sigma': array([-2.44957927])},
#   'tau': {'mean': array([-3.23855313]), 'sigma': array([-1.95424494])}},
#  {'mu': {'mean': array([-0.22595203]), 'sigma': array([-2.44704874])},
#   'tau': {'mean': array([-3.23716593]), 'sigma': array([-1.95446594])}},
#  {'mu': {'mean': array([-0.21857637]), 'sigma': array([-2.44509378])},
#   'tau': {'mean': array([-3.23507663]), 'sigma': array([-1.95466825])}},
#  {'mu': {'mean': array([-0.21157688]), 'sigma': array([-2.44300496])},
#   'tau': {'mean': array([-3.2308053]), 'sigma': array([-1.95494247])}},
#  {'mu': {'mean': array([-0.20512221]), 'sigma': array([-2.44074883])},
#   'tau': {'mean': array([-3.2255189]), 'sigma': array([-1.95521542])}},
#  {'mu': {'mean': array([-0.19899352]), 'sigma': array([-2.43835567])},
#   'tau': {'mean': array([-3.2202102]), 'sigma': array([-1.95545946])}},
#  {'mu': {'mean': array([-0.19309303]), 'sigma': array([-2.43586351])},
#   'tau': {'mean': array([-3.21566252]), 'sigma': array([-1.95567612])}},
#  {'mu': {'mean': array([-0.18771657]), 'sigma': array([-2.43327064])},
#   'tau': {'mean': array([-3.20984138]), 'sigma': array([-1.95591788])}},
#  {'mu': {'mean': array([-0.18239999]), 'sigma': array([-2.43068369])},
#   'tau': {'mean': array([-3.20459449]), 'sigma': array([-1.9561307])}},
#  {'mu': {'mean': array([-0.17707776]), 'sigma': array([-2.42823389])},
#   'tau': {'mean': array([-3.19806755]), 'sigma': array([-1.95637834])}},
#  {'mu': {'mean': array([-0.1717348]), 'sigma': array([-2.42591869])},
#   'tau': {'mean': array([-3.1908353]), 'sigma': array([-1.95663196])}},
#  {'mu': {'mean': array([-0.16683578]), 'sigma': array([-2.42348158])},
#   'tau': {'mean': array([-3.18057545]), 'sigma': array([-1.95714884])}},
#  {'mu': {'mean': array([-0.16182443]), 'sigma': array([-2.42123467])},
#   'tau': {'mean': array([-3.17068279]), 'sigma': array([-1.95762068])}},
#  {'mu': {'mean': array([-0.15693887]), 'sigma': array([-2.41892963])},
#   'tau': {'mean': array([-3.16126094]), 'sigma': array([-1.95804913])}},
#  {'mu': {'mean': array([-0.15204769]), 'sigma': array([-2.41665492])},
#   'tau': {'mean': array([-3.15336592]), 'sigma': array([-1.95843054])}},
#  {'mu': {'mean': array([-0.14764104]), 'sigma': array([-2.41427573])},
#   'tau': {'mean': array([-3.14454779]), 'sigma': array([-1.95884042])}},
#  {'mu': {'mean': array([-0.14259798]), 'sigma': array([-2.41252751])},
#   'tau': {'mean': array([-3.14286495]), 'sigma': array([-1.95966949])}},
#  {'mu': {'mean': array([-0.13829715]), 'sigma': array([-2.41078225])},
#   'tau': {'mean': array([-3.14255322]), 'sigma': array([-1.96041941])}},
#  {'mu': {'mean': array([-0.13461667]), 'sigma': array([-2.40899862])},
#   'tau': {'mean': array([-3.14132095]), 'sigma': array([-1.96111969])}},
#  {'mu': {'mean': array([-0.13114645]), 'sigma': array([-2.40703823])},
#   'tau': {'mean': array([-3.1431173]), 'sigma': array([-1.96183444])}},
#  {'mu': {'mean': array([-0.12727853]), 'sigma': array([-2.40554176])},
#   'tau': {'mean': array([-3.14411065]), 'sigma': array([-1.96248971])}},
#  {'mu': {'mean': array([-0.12363384]), 'sigma': array([-2.40385315])},
#   'tau': {'mean': array([-3.14373633]), 'sigma': array([-1.96312091])}},
#  {'mu': {'mean': array([-0.11942046]), 'sigma': array([-2.40274967])},
#   'tau': {'mean': array([-3.14643683]), 'sigma': array([-1.96378144])}},
#  {'mu': {'mean': array([-0.11584149]), 'sigma': array([-2.40152628])},
#   'tau': {'mean': array([-3.15106938]), 'sigma': array([-1.96441775])}},
#  {'mu': {'mean': array([-0.11234931]), 'sigma': array([-2.40014086])},
#   'tau': {'mean': array([-3.15342747]), 'sigma': array([-1.96506724])}},
#  {'mu': {'mean': array([-0.10920585]), 'sigma': array([-2.39855252])},
#   'tau': {'mean': array([-3.1544157]), 'sigma': array([-1.96568314])}},
#  {'mu': {'mean': array([-0.10614674]), 'sigma': array([-2.39680805])},
#   'tau': {'mean': array([-3.15520742]), 'sigma': array([-1.9662346])}},
#  {'mu': {'mean': array([-0.10324069]), 'sigma': array([-2.39489665])},
#   'tau': {'mean': array([-3.15621353]), 'sigma': array([-1.96672473])}},
#  {'mu': {'mean': array([-0.1005112]), 'sigma': array([-2.39283017])},
#   'tau': {'mean': array([-3.15568515]), 'sigma': array([-1.96721241])}},
#  {'mu': {'mean': array([-0.09808609]), 'sigma': array([-2.39062915])},
#   'tau': {'mean': array([-3.15201294]), 'sigma': array([-1.96787001])}},
#  {'mu': {'mean': array([-0.09575046]), 'sigma': array([-2.38830916])},
#   'tau': {'mean': array([-3.14842502]), 'sigma': array([-1.96846214])}},
#  {'mu': {'mean': array([-0.09398187]), 'sigma': array([-2.38602951])},
#   'tau': {'mean': array([-3.14938622]), 'sigma': array([-1.96918871])}},
#  {'mu': {'mean': array([-0.09214107]), 'sigma': array([-2.38368873])},
#   'tau': {'mean': array([-3.14893824]), 'sigma': array([-1.96988417])}},
#  {'mu': {'mean': array([-0.09039396]), 'sigma': array([-2.38123028])},
#   'tau': {'mean': array([-3.14738136]), 'sigma': array([-1.97054254])}},
#  {'mu': {'mean': array([-0.08840262]), 'sigma': array([-2.37896284])},
#   'tau': {'mean': array([-3.14169873]), 'sigma': array([-1.9715349])}},
#  {'mu': {'mean': array([-0.08678379]), 'sigma': array([-2.37662464])},
#   'tau': {'mean': array([-3.13660823]), 'sigma': array([-1.97242413])}},
#  {'mu': {'mean': array([-0.08493839]), 'sigma': array([-2.37429546])},
#   'tau': {'mean': array([-3.13517842]), 'sigma': array([-1.97331759])}},
#  {'mu': {'mean': array([-0.08303652]), 'sigma': array([-2.37188837])},
#   'tau': {'mean': array([-3.13638858]), 'sigma': array([-1.9741714])}},
#  {'mu': {'mean': array([-0.08209134]), 'sigma': array([-2.37025821])},
#   'tau': {'mean': array([-3.13672313]), 'sigma': array([-1.97495719])}},
#  {'mu': {'mean': array([-0.08145368]), 'sigma': array([-2.36851942])},
#   'tau': {'mean': array([-3.13479682]), 'sigma': array([-1.97577912])}},
#  {'mu': {'mean': array([-0.08008574]), 'sigma': array([-2.36723464])},
#   'tau': {'mean': array([-3.1362429]), 'sigma': array([-1.97660955])}},
#  {'mu': {'mean': array([-0.07916491]), 'sigma': array([-2.36585031])},
#   'tau': {'mean': array([-3.13938724]), 'sigma': array([-1.97737519])}},
#  {'mu': {'mean': array([-0.07788343]), 'sigma': array([-2.36441776])},
#   'tau': {'mean': array([-3.14762973]), 'sigma': array([-1.97837278])}},
#  {'mu': {'mean': array([-0.07659793]), 'sigma': array([-2.36278207])},
#   'tau': {'mean': array([-3.15634084]), 'sigma': array([-1.97927516])}},
#  {'mu': {'mean': array([-0.07550473]), 'sigma': array([-2.36095637])},
#   'tau': {'mean': array([-3.16167729]), 'sigma': array([-1.98021971])}},
#  {'mu': {'mean': array([-0.07423324]), 'sigma': array([-2.35904407])},
#   'tau': {'mean': array([-3.16695014]), 'sigma': array([-1.98106478])}},
#  {'mu': {'mean': array([-0.07360309]), 'sigma': array([-2.35729455])},
#   'tau': {'mean': array([-3.17286423]), 'sigma': array([-1.98183115])}},
#  {'mu': {'mean': array([-0.07334992]), 'sigma': array([-2.35563602])},
#   'tau': {'mean': array([-3.1798894]), 'sigma': array([-1.98251038])}},
#  {'mu': {'mean': array([-0.07277504]), 'sigma': array([-2.35398925])},
#   'tau': {'mean': array([-3.18559046]), 'sigma': array([-1.9831287])}},
#  {'mu': {'mean': array([-0.07277062]), 'sigma': array([-2.3526146])},
#   'tau': {'mean': array([-3.18933791]), 'sigma': array([-1.98372308])}},
#  {'mu': {'mean': array([-0.07229531]), 'sigma': array([-2.35127769])},
#   'tau': {'mean': array([-3.19701628]), 'sigma': array([-1.98451127])}},
#  {'mu': {'mean': array([-0.07205101]), 'sigma': array([-2.34978961])},
#   'tau': {'mean': array([-3.20512354]), 'sigma': array([-1.98523709])}},
#  {'mu': {'mean': array([-0.07140329]), 'sigma': array([-2.348356])},
#   'tau': {'mean': array([-3.21332522]), 'sigma': array([-1.9858989])}},
#  {'mu': {'mean': array([-0.07092383]), 'sigma': array([-2.34675074])},
#   'tau': {'mean': array([-3.21889639]), 'sigma': array([-1.98654862])}},
#  {'mu': {'mean': array([-0.07082047]), 'sigma': array([-2.3451382])},
#   'tau': {'mean': array([-3.22312207]), 'sigma': array([-1.98713838])}},
#  {'mu': {'mean': array([-0.07086157]), 'sigma': array([-2.34338137])},
#   'tau': {'mean': array([-3.22505043]), 'sigma': array([-1.98772247])}},
#  {'mu': {'mean': array([-0.0713223]), 'sigma': array([-2.34173027])},
#   'tau': {'mean': array([-3.22633354]), 'sigma': array([-1.98824566])}},
#  {'mu': {'mean': array([-0.07096171]), 'sigma': array([-2.3406431])},
#   'tau': {'mean': array([-3.2294129]), 'sigma': array([-1.98877724])}},
#  {'mu': {'mean': array([-0.0705174]), 'sigma': array([-2.33935025])},
#   'tau': {'mean': array([-3.22964117]), 'sigma': array([-1.98935862])}},
#  {'mu': {'mean': array([-0.06961684]), 'sigma': array([-2.338281])},
#   'tau': {'mean': array([-3.22727642]), 'sigma': array([-1.98998722])}},
#  {'mu': {'mean': array([-0.06893437]), 'sigma': array([-2.33700744])},
#   'tau': {'mean': array([-3.22310648]), 'sigma': array([-1.99061402])}},
#  {'mu': {'mean': array([-0.06862881]), 'sigma': array([-2.33567473])},
#   'tau': {'mean': array([-3.21766702]), 'sigma': array([-1.99121763])}},
#  {'mu': {'mean': array([-0.06867718]), 'sigma': array([-2.33427317])},
#   'tau': {'mean': array([-3.21337841]), 'sigma': array([-1.99176409])}},
#  {'mu': {'mean': array([-0.06842458]), 'sigma': array([-2.33282775])},
#   'tau': {'mean': array([-3.20644142]), 'sigma': array([-1.9924221])}},
#  {'mu': {'mean': array([-0.06840986]), 'sigma': array([-2.33124852])},
#   'tau': {'mean': array([-3.19959008]), 'sigma': array([-1.99301591])}},
#  {'mu': {'mean': array([-0.06886162]), 'sigma': array([-2.32982193])},
#   'tau': {'mean': array([-3.19181323]), 'sigma': array([-1.99359287])}},
#  {'mu': {'mean': array([-0.06877762]), 'sigma': array([-2.32849799])},
#   'tau': {'mean': array([-3.1860635]), 'sigma': array([-1.99412848])}},
#  {'mu': {'mean': array([-0.06891191]), 'sigma': array([-2.32701502])},
#   'tau': {'mean': array([-3.18230309]), 'sigma': array([-1.99463118])}},
#  {'mu': {'mean': array([-0.06921342]), 'sigma': array([-2.32538331])},
#   'tau': {'mean': array([-3.17736965]), 'sigma': array([-1.99512779])}},
#  {'mu': {'mean': array([-0.06927151]), 'sigma': array([-2.32363897])},
#   'tau': {'mean': array([-3.17098406]), 'sigma': array([-1.99564741])}},
#  {'mu': {'mean': array([-0.06937841]), 'sigma': array([-2.32172303])},
#   'tau': {'mean': array([-3.16619297]), 'sigma': array([-1.99611763])}},
#  {'mu': {'mean': array([-0.06942876]), 'sigma': array([-2.31965018])},
#   'tau': {'mean': array([-3.16256744]), 'sigma': array([-1.99653754])}},
#  {'mu': {'mean': array([-0.06923095]), 'sigma': array([-2.31751667])},
#   'tau': {'mean': array([-3.15859711]), 'sigma': array([-1.99692516])}},
#  {'mu': {'mean': array([-0.06905784]), 'sigma': array([-2.31524322])},
#   'tau': {'mean': array([-3.15365471]), 'sigma': array([-1.99731414])}},
#  {'mu': {'mean': array([-0.06956857]), 'sigma': array([-2.31333078])},
#   'tau': {'mean': array([-3.1524456]), 'sigma': array([-1.99777413])}},
#  {'mu': {'mean': array([-0.06994754]), 'sigma': array([-2.3112623])},
#   'tau': {'mean': array([-3.15418172]), 'sigma': array([-1.99826701])}},
#  {'mu': {'mean': array([-0.0695684]), 'sigma': array([-2.30954548])},
#   'tau': {'mean': array([-3.16112309]), 'sigma': array([-1.99903671])}},
#  {'mu': {'mean': array([-0.06912232]), 'sigma': array([-2.30765514])},
#   'tau': {'mean': array([-3.17196662]), 'sigma': array([-1.99997108])}},
#  {'mu': {'mean': array([-0.06837771]), 'sigma': array([-2.30574169])},
#   'tau': {'mean': array([-3.18289431]), 'sigma': array([-2.00081942])}},
#  {'mu': {'mean': array([-0.06783169]), 'sigma': array([-2.30368171])},
#   'tau': {'mean': array([-3.19336771]), 'sigma': array([-2.00158143])}},
#  {'mu': {'mean': array([-0.06703353]), 'sigma': array([-2.30160251])},
#   'tau': {'mean': array([-3.20201739]), 'sigma': array([-2.00227552])}},
#  {'mu': {'mean': array([-0.06619807]), 'sigma': array([-2.29938628])},
#   'tau': {'mean': array([-3.21343616]), 'sigma': array([-2.00307639])}},
#  {'mu': {'mean': array([-0.06502261]), 'sigma': array([-2.29720551])},
#   'tau': {'mean': array([-3.22916598]), 'sigma': array([-2.00419561])}},
#  {'mu': {'mean': array([-0.06411907]), 'sigma': array([-2.2949147])},
#   'tau': {'mean': array([-3.24195039]), 'sigma': array([-2.00522499])}},
#  {'mu': {'mean': array([-0.06356226]), 'sigma': array([-2.29258034])},
#   'tau': {'mean': array([-3.25242525]), 'sigma': array([-2.0061577])}},
#  {'mu': {'mean': array([-0.06290028]), 'sigma': array([-2.2901559])},
#   'tau': {'mean': array([-3.26075108]), 'sigma': array([-2.00700243])}},
#  {'mu': {'mean': array([-0.06257025]), 'sigma': array([-2.2877105])},
#   'tau': {'mean': array([-3.26640513]), 'sigma': array([-2.00779417])}},
#  {'mu': {'mean': array([-0.06275079]), 'sigma': array([-2.28543121])},
#   'tau': {'mean': array([-3.27153524]), 'sigma': array([-2.00850262])}},
#  {'mu': {'mean': array([-0.06307856]), 'sigma': array([-2.283043])},
#   'tau': {'mean': array([-3.27699301]), 'sigma': array([-2.00915747])}},
#  {'mu': {'mean': array([-0.06334629]), 'sigma': array([-2.28052822])},
#   'tau': {'mean': array([-3.28040368]), 'sigma': array([-2.00975641])}},
#  {'mu': {'mean': array([-0.06344845]), 'sigma': array([-2.27793118])},
#   'tau': {'mean': array([-3.28079785]), 'sigma': array([-2.01037027])}},
#  {'mu': {'mean': array([-0.0635875]), 'sigma': array([-2.27522646])},
#   'tau': {'mean': array([-3.28032029]), 'sigma': array([-2.01091548])}},
#  {'mu': {'mean': array([-0.0637799]), 'sigma': array([-2.27242691])},
#   'tau': {'mean': array([-3.27826833]), 'sigma': array([-2.01141806])}},
#  {'mu': {'mean': array([-0.06368842]), 'sigma': array([-2.26964297])},
#   'tau': {'mean': array([-3.27498877]), 'sigma': array([-2.01187608])}},
#  {'mu': {'mean': array([-0.0636291]), 'sigma': array([-2.26676541])},
#   'tau': {'mean': array([-3.27267623]), 'sigma': array([-2.0122987])}},
#  {'mu': {'mean': array([-0.0646613]), 'sigma': array([-2.26539735])},
#   'tau': {'mean': array([-3.26978077]), 'sigma': array([-2.01267322])}},
#  {'mu': {'mean': array([-0.06537666]), 'sigma': array([-2.26386469])},
#   'tau': {'mean': array([-3.26593647]), 'sigma': array([-2.01301216])}},
#  {'mu': {'mean': array([-0.06621205]), 'sigma': array([-2.26215565])},
#   'tau': {'mean': array([-3.26284294]), 'sigma': array([-2.01331843])}},
#  {'mu': {'mean': array([-0.0678107]), 'sigma': array([-2.26099925])},
#   'tau': {'mean': array([-3.2629261]), 'sigma': array([-2.01373672])}},
#  {'mu': {'mean': array([-0.06937978]), 'sigma': array([-2.2596045])},
#   'tau': {'mean': array([-3.26385039]), 'sigma': array([-2.01412856])}},
#  {'mu': {'mean': array([-0.07082059]), 'sigma': array([-2.25797589])},
#   'tau': {'mean': array([-3.26444632]), 'sigma': array([-2.01447357])}},
#  {'mu': {'mean': array([-0.07193225]), 'sigma': array([-2.25617689])},
#   'tau': {'mean': array([-3.26536038]), 'sigma': array([-2.01478517])}},
#  {'mu': {'mean': array([-0.07251006]), 'sigma': array([-2.25442638])},
#   'tau': {'mean': array([-3.26493734]), 'sigma': array([-2.01506864])}},
#  {'mu': {'mean': array([-0.07290134]), 'sigma': array([-2.25249527])},
#   'tau': {'mean': array([-3.26306983]), 'sigma': array([-2.01533408])}},
#  {'mu': {'mean': array([-0.07313505]), 'sigma': array([-2.25039435])},
#   'tau': {'mean': array([-3.26158596]), 'sigma': array([-2.01557011])}},
#  {'mu': {'mean': array([-0.07367123]), 'sigma': array([-2.24825283])},
#   'tau': {'mean': array([-3.26151882]), 'sigma': array([-2.01581467])}},
#  {'mu': {'mean': array([-0.07390272]), 'sigma': array([-2.24602167])},
#   'tau': {'mean': array([-3.2610966]), 'sigma': array([-2.01602653])}},
#  {'mu': {'mean': array([-0.07384095]), 'sigma': array([-2.24372797])},
#   'tau': {'mean': array([-3.25928503]), 'sigma': array([-2.01622636])}},
#  {'mu': {'mean': array([-0.07397422]), 'sigma': array([-2.24132839])},
#   'tau': {'mean': array([-3.25819294]), 'sigma': array([-2.01641051])}},
#  {'mu': {'mean': array([-0.07415636]), 'sigma': array([-2.23879117])},
#   'tau': {'mean': array([-3.2579631]), 'sigma': array([-2.01658673])}},
#  {'mu': {'mean': array([-0.07382664]), 'sigma': array([-2.23640521])},
#   'tau': {'mean': array([-3.25833064]), 'sigma': array([-2.01675019])}},
#  {'mu': {'mean': array([-0.07279548]), 'sigma': array([-2.23448709])},
#   'tau': {'mean': array([-3.2596433]), 'sigma': array([-2.01691543])}},
#  {'mu': {'mean': array([-0.07206459]), 'sigma': array([-2.23243274])},
#   'tau': {'mean': array([-3.25962911]), 'sigma': array([-2.01706623])}},
#  {'mu': {'mean': array([-0.07129392]), 'sigma': array([-2.2302128])},
#   'tau': {'mean': array([-3.258531]), 'sigma': array([-2.01720121])}},
#  {'mu': {'mean': array([-0.0708409]), 'sigma': array([-2.2279136])},
#   'tau': {'mean': array([-3.2555799]), 'sigma': array([-2.01735462])}},
#  {'mu': {'mean': array([-0.0697837]), 'sigma': array([-2.22593074])},
#   'tau': {'mean': array([-3.25416828]), 'sigma': array([-2.01752121])}},
#  {'mu': {'mean': array([-0.06863967]), 'sigma': array([-2.22379857])},
#   'tau': {'mean': array([-3.25405332]), 'sigma': array([-2.01769553])}},
#  {'mu': {'mean': array([-0.06742853]), 'sigma': array([-2.22153315])},
#   'tau': {'mean': array([-3.25279654]), 'sigma': array([-2.01785448])}},
#  {'mu': {'mean': array([-0.06624963]), 'sigma': array([-2.21911432])},
#   'tau': {'mean': array([-3.25041512]), 'sigma': array([-2.01800234])}},
#  {'mu': {'mean': array([-0.06442412]), 'sigma': array([-2.21726663])},
#   'tau': {'mean': array([-3.24828175]), 'sigma': array([-2.01812919])}},
#  {'mu': {'mean': array([-0.06305066]), 'sigma': array([-2.21531492])},
#   'tau': {'mean': array([-3.24399654]), 'sigma': array([-2.01830304])}},
#  {'mu': {'mean': array([-0.06219295]), 'sigma': array([-2.21338624])},
#   'tau': {'mean': array([-3.2366316]), 'sigma': array([-2.01862477])}},
#  {'mu': {'mean': array([-0.06142884]), 'sigma': array([-2.21125719])},
#   'tau': {'mean': array([-3.22882173]), 'sigma': array([-2.01892107])}},
#  {'mu': {'mean': array([-0.06008715]), 'sigma': array([-2.20949848])},
#   'tau': {'mean': array([-3.22141133]), 'sigma': array([-2.01918192])}},
#  {'mu': {'mean': array([-0.05882321]), 'sigma': array([-2.2075267])},
#   'tau': {'mean': array([-3.21542826]), 'sigma': array([-2.01941956])}},
#  {'mu': {'mean': array([-0.05677858]), 'sigma': array([-2.20653665])},
#   'tau': {'mean': array([-3.20804617]), 'sigma': array([-2.01968499])}},
#  {'mu': {'mean': array([-0.05521243]), 'sigma': array([-2.20533234])},
#   'tau': {'mean': array([-3.20096192]), 'sigma': array([-2.01992016])}},
#  {'mu': {'mean': array([-0.05351659]), 'sigma': array([-2.20396269])},
#   'tau': {'mean': array([-3.19516886]), 'sigma': array([-2.02012971])}},
#  {'mu': {'mean': array([-0.0518983]), 'sigma': array([-2.20234902])},
#   'tau': {'mean': array([-3.1893097]), 'sigma': array([-2.02031933])}},
#  {'mu': {'mean': array([-0.05050009]), 'sigma': array([-2.20049844])},
#   'tau': {'mean': array([-3.1847454]), 'sigma': array([-2.02048807])}},
#  {'mu': {'mean': array([-0.04996242]), 'sigma': array([-2.19896509])},
#   'tau': {'mean': array([-3.18162867]), 'sigma': array([-2.02064217])}},
#  {'mu': {'mean': array([-0.04929702]), 'sigma': array([-2.197241])},
#   'tau': {'mean': array([-3.17816771]), 'sigma': array([-2.02078394])}},
#  {'mu': {'mean': array([-0.04836594]), 'sigma': array([-2.19542429])},
#   'tau': {'mean': array([-3.17838534]), 'sigma': array([-2.02102755])}},
#  {'mu': {'mean': array([-0.04765109]), 'sigma': array([-2.19339628])},
#   'tau': {'mean': array([-3.17763269]), 'sigma': array([-2.02125922])}},
#  {'mu': {'mean': array([-0.04707076]), 'sigma': array([-2.19116687])},
#   'tau': {'mean': array([-3.17837729]), 'sigma': array([-2.02147971])}},
#  {'mu': {'mean': array([-0.04698586]), 'sigma': array([-2.18896015])},
#   'tau': {'mean': array([-3.17795155]), 'sigma': array([-2.02169595])}},
#  {'mu': {'mean': array([-0.04647194]), 'sigma': array([-2.18677923])},
#   'tau': {'mean': array([-3.18294246]), 'sigma': array([-2.02220106])}},
#  {'mu': {'mean': array([-0.04579673]), 'sigma': array([-2.1844871])},
#   'tau': {'mean': array([-3.18670662]), 'sigma': array([-2.02266119])}},
#  {'mu': {'mean': array([-0.04543625]), 'sigma': array([-2.18207649])},
#   'tau': {'mean': array([-3.1880498]), 'sigma': array([-2.02314063])}},
#  {'mu': {'mean': array([-0.04428168]), 'sigma': array([-2.18055203])},
#   'tau': {'mean': array([-3.18669755]), 'sigma': array([-2.02367705])}},
#  {'mu': {'mean': array([-0.04370633]), 'sigma': array([-2.17890295])},
#   'tau': {'mean': array([-3.19207841]), 'sigma': array([-2.02463565])}},
#  {'mu': {'mean': array([-0.04295494]), 'sigma': array([-2.17708882])},
#   'tau': {'mean': array([-3.20028017]), 'sigma': array([-2.02562434])}},
#  {'mu': {'mean': array([-0.04269132]), 'sigma': array([-2.17518798])},
#   'tau': {'mean': array([-3.20880065]), 'sigma': array([-2.02652423])}},
#  {'mu': {'mean': array([-0.04262671]), 'sigma': array([-2.17307534])},
#   'tau': {'mean': array([-3.22084545]), 'sigma': array([-2.02756432])}},
#  {'mu': {'mean': array([-0.04292392]), 'sigma': array([-2.17083905])},
#   'tau': {'mean': array([-3.23590418]), 'sigma': array([-2.0287247])}},
#  {'mu': {'mean': array([-0.04328093]), 'sigma': array([-2.16841525])},
#   'tau': {'mean': array([-3.24730931]), 'sigma': array([-2.02981991])}},
#  {'mu': {'mean': array([-0.04352179]), 'sigma': array([-2.16583762])},
#   'tau': {'mean': array([-3.25748115]), 'sigma': array([-2.03079968])}},
#  {'mu': {'mean': array([-0.04383536]), 'sigma': array([-2.16338174])},
#   'tau': {'mean': array([-3.26607527]), 'sigma': array([-2.03159395])}},
#  {'mu': {'mean': array([-0.04355011]), 'sigma': array([-2.16133204])},
#   'tau': {'mean': array([-3.27205954]), 'sigma': array([-2.03233208])}},
#  {'mu': {'mean': array([-0.04397429]), 'sigma': array([-2.15971204])},
#   'tau': {'mean': array([-3.2757981]), 'sigma': array([-2.0330128])}},
#  {'mu': {'mean': array([-0.04474609]), 'sigma': array([-2.15807003])},
#   'tau': {'mean': array([-3.27681062]), 'sigma': array([-2.03367687])}},
#  {'mu': {'mean': array([-0.0450849]), 'sigma': array([-2.15638664])},
#   'tau': {'mean': array([-3.28121112]), 'sigma': array([-2.03448733])}},
#  {'mu': {'mean': array([-0.04544021]), 'sigma': array([-2.15449508])},
#   'tau': {'mean': array([-3.28350441]), 'sigma': array([-2.03522961])}},
#  {'mu': {'mean': array([-0.0450471]), 'sigma': array([-2.15318392])},
#   'tau': {'mean': array([-3.28460351]), 'sigma': array([-2.03589151])}},
#  {'mu': {'mean': array([-0.04483473]), 'sigma': array([-2.15164703])},
#   'tau': {'mean': array([-3.28213157]), 'sigma': array([-2.03662775])}},
#  {'mu': {'mean': array([-0.04464435]), 'sigma': array([-2.14988693])},
#   'tau': {'mean': array([-3.27822844]), 'sigma': array([-2.03730243])}},
#  {'mu': {'mean': array([-0.04456188]), 'sigma': array([-2.14792616])},
#   'tau': {'mean': array([-3.27402263]), 'sigma': array([-2.037901])}},
#  {'mu': {'mean': array([-0.04468877]), 'sigma': array([-2.14581224])},
#   'tau': {'mean': array([-3.27029801]), 'sigma': array([-2.03843534])}},
#  {'mu': {'mean': array([-0.04492476]), 'sigma': array([-2.14354043])},
#   'tau': {'mean': array([-3.26395694]), 'sigma': array([-2.03901698])}},
#  {'mu': {'mean': array([-0.04501209]), 'sigma': array([-2.14114534])},
#   'tau': {'mean': array([-3.26034714]), 'sigma': array([-2.03962293])}},
#  {'mu': {'mean': array([-0.045032]), 'sigma': array([-2.13861885])},
#   'tau': {'mean': array([-3.2559343]), 'sigma': array([-2.04017012])}},
#  {'mu': {'mean': array([-0.04393177]), 'sigma': array([-2.13753831])},
#   'tau': {'mean': array([-3.25308484]), 'sigma': array([-2.04068636])}},
#  {'mu': {'mean': array([-0.04351485]), 'sigma': array([-2.13656265])},
#   'tau': {'mean': array([-3.24964237]), 'sigma': array([-2.04114843])}},
#  {'mu': {'mean': array([-0.04351653]), 'sigma': array([-2.1354267])},
#   'tau': {'mean': array([-3.2476984]), 'sigma': array([-2.04158835])}},
#  {'mu': {'mean': array([-0.04346816]), 'sigma': array([-2.13403073])},
#   'tau': {'mean': array([-3.24516922]), 'sigma': array([-2.04198073])}},
#  {'mu': {'mean': array([-0.04381953]), 'sigma': array([-2.1325303])},
#   'tau': {'mean': array([-3.24379279]), 'sigma': array([-2.04234708])}},
#  {'mu': {'mean': array([-0.04476851]), 'sigma': array([-2.13113092])},
#   'tau': {'mean': array([-3.24595123]), 'sigma': array([-2.04285114])}},
#  {'mu': {'mean': array([-0.04567405]), 'sigma': array([-2.12948437])},
#   'tau': {'mean': array([-3.24835564]), 'sigma': array([-2.04330599])}},
#  {'mu': {'mean': array([-0.04689681]), 'sigma': array([-2.12776468])},
#   'tau': {'mean': array([-3.25172119]), 'sigma': array([-2.04374037])}},
#  {'mu': {'mean': array([-0.04880784]), 'sigma': array([-2.12647536])},
#   'tau': {'mean': array([-3.25654178]), 'sigma': array([-2.04418626])}},
#  {'mu': {'mean': array([-0.05024773]), 'sigma': array([-2.12505681])},
#   'tau': {'mean': array([-3.26014001]), 'sigma': array([-2.04458205])}},
#  {'mu': {'mean': array([-0.05179533]), 'sigma': array([-2.12345594])},
#   'tau': {'mean': array([-3.26209166]), 'sigma': array([-2.04494283])}},
#  {'mu': {'mean': array([-0.05296576]), 'sigma': array([-2.12170909])},
#   'tau': {'mean': array([-3.26297207]), 'sigma': array([-2.04526258])}},
#  {'mu': {'mean': array([-0.05383123]), 'sigma': array([-2.11979875])},
#   'tau': {'mean': array([-3.2660576]), 'sigma': array([-2.04564314])}},
#  {'mu': {'mean': array([-0.05413536]), 'sigma': array([-2.11806529])},
#   'tau': {'mean': array([-3.26585768]), 'sigma': array([-2.04608453])}},
#  {'mu': {'mean': array([-0.05391902]), 'sigma': array([-2.1164092])},
#   'tau': {'mean': array([-3.26742493]), 'sigma': array([-2.04653973])}},
#  {'mu': {'mean': array([-0.05330307]), 'sigma': array([-2.1148224])},
#   'tau': {'mean': array([-3.26588463]), 'sigma': array([-2.04704431])}},
#  {'mu': {'mean': array([-0.05216111]), 'sigma': array([-2.11346255])},
#   'tau': {'mean': array([-3.26443852]), 'sigma': array([-2.04749189])}},
#  {'mu': {'mean': array([-0.0508455]), 'sigma': array([-2.11197001])},
#   'tau': {'mean': array([-3.2625965]), 'sigma': array([-2.04788631])}},
#  {'mu': {'mean': array([-0.0490155]), 'sigma': array([-2.11083383])},
#   'tau': {'mean': array([-3.25963425]), 'sigma': array([-2.04824529])}},
#  {'mu': {'mean': array([-0.04762325]), 'sigma': array([-2.10948167])},
#   'tau': {'mean': array([-3.25595512]), 'sigma': array([-2.04856581])}},
#  {'mu': {'mean': array([-0.046737]), 'sigma': array([-2.10801205])},
#   'tau': {'mean': array([-3.25165608]), 'sigma': array([-2.04885195])}},
# ...
#  {'mu': {'mean': array([-0.02680989]), 'sigma': array([-2.01627076])},
#   'tau': {'mean': array([-3.19225738]), 'sigma': array([-2.07288817])}},
#  {'mu': {'mean': array([-0.02887643]), 'sigma': array([-2.0145041])},
#   'tau': {'mean': array([-3.19665519]), 'sigma': array([-2.07319562])}},
#  {'mu': {'mean': array([-0.03093862]), 'sigma': array([-2.01249124])},
#   'tau': {'mean': array([-3.19983672]), 'sigma': array([-2.07347519])}},
#  {'mu': {'mean': array([-0.03361603]), 'sigma': array([-2.01079492])},
#   'tau': {'mean': array([-3.20395648]), 'sigma': array([-2.07373721])}},
#  {'mu': {'mean': array([-0.03564321]), 'sigma': array([-2.00904005])},
#   'tau': {'mean': array([-3.20941705]), 'sigma': array([-2.07400259])}},
#  {'mu': {'mean': array([-0.03733288]), 'sigma': array([-2.00707087])},
#   'tau': {'mean': array([-3.210666]), 'sigma': array([-2.07442748])}},
#  {'mu': {'mean': array([-0.03881268]), 'sigma': array([-2.00486996])},
#   'tau': {'mean': array([-3.20919948]), 'sigma': array([-2.07489448])}},
#  {'mu': {'mean': array([-0.04005091]), 'sigma': array([-2.00247236])},
#   'tau': {'mean': array([-3.21034502]), 'sigma': array([-2.07538294])}},
#  {'mu': {'mean': array([-0.04246701]), 'sigma': array([-2.00168535])},
#   'tau': {'mean': array([-3.21030181]), 'sigma': array([-2.07583139])}},
#  {'mu': {'mean': array([-0.04448369]), 'sigma': array([-2.00058076])},
#   'tau': {'mean': array([-3.21447843]), 'sigma': array([-2.076437])}},
#  {'mu': {'mean': array([-0.04575843]), 'sigma': array([-1.99948874])},
#   'tau': {'mean': array([-3.21770447]), 'sigma': array([-2.07692167])}},
#  {'mu': {'mean': array([-0.04760671]), 'sigma': array([-1.99857845])},
#   'tau': {'mean': array([-3.22207962]), 'sigma': array([-2.07738425])}},
#  {'mu': {'mean': array([-0.0493275]), 'sigma': array([-1.99736233])},
#   'tau': {'mean': array([-3.22503437]), 'sigma': array([-2.07780549])}},
#  {'mu': {'mean': array([-0.05130131]), 'sigma': array([-1.99611054])},
#   'tau': {'mean': array([-3.22428297]), 'sigma': array([-2.07835128])}},
#  {'mu': {'mean': array([-0.05394067]), 'sigma': array([-1.99549255])},
#   'tau': {'mean': array([-3.22229047]), 'sigma': array([-2.07885778])}},
#  {'mu': {'mean': array([-0.0568636]), 'sigma': array([-1.99480856])},
#   'tau': {'mean': array([-3.22301642]), 'sigma': array([-2.07939947])}},
#  {'mu': {'mean': array([-0.06009504]), 'sigma': array([-1.99423349])},
#   'tau': {'mean': array([-3.22223883]), 'sigma': array([-2.07990659])}},
#  {'mu': {'mean': array([-0.06301407]), 'sigma': array([-1.99331757])},
#   'tau': {'mean': array([-3.22171495]), 'sigma': array([-2.0803579])}},
#  {'mu': {'mean': array([-0.06540492]), 'sigma': array([-1.99216421])},
#   'tau': {'mean': array([-3.22236943]), 'sigma': array([-2.0807788])}},
#  {'mu': {'mean': array([-0.06710019]), 'sigma': array([-1.99094583])},
#   'tau': {'mean': array([-3.22577144]), 'sigma': array([-2.08126342])}},
#  {'mu': {'mean': array([-0.06887209]), 'sigma': array([-1.98951933])},
#   'tau': {'mean': array([-3.22839333]), 'sigma': array([-2.08169439])}},
#  {'mu': {'mean': array([-0.0702026]), 'sigma': array([-1.98790335])},
#   'tau': {'mean': array([-3.23405223]), 'sigma': array([-2.08223042])}},
#  {'mu': {'mean': array([-0.07134848]), 'sigma': array([-1.98605001])},
#   'tau': {'mean': array([-3.23714791]), 'sigma': array([-2.08275489])}},
#  {'mu': {'mean': array([-0.07252932]), 'sigma': array([-1.98400776])},
#   'tau': {'mean': array([-3.23897729]), 'sigma': array([-2.08322775])}},
#  {'mu': {'mean': array([-0.07446214]), 'sigma': array([-1.98272322])},
#   'tau': {'mean': array([-3.23977138]), 'sigma': array([-2.08365205])}},
#  {'mu': {'mean': array([-0.0756628]), 'sigma': array([-1.98142337])},
#   'tau': {'mean': array([-3.244639]), 'sigma': array([-2.08427165])}},
#  {'mu': {'mean': array([-0.0759554]), 'sigma': array([-1.98055509])},
#   'tau': {'mean': array([-3.24915003]), 'sigma': array([-2.08482439])}},
#  {'mu': {'mean': array([-0.07532705]), 'sigma': array([-1.98030535])},
#   'tau': {'mean': array([-3.25278864]), 'sigma': array([-2.08531456])}},
#  {'mu': {'mean': array([-0.07496768]), 'sigma': array([-1.97973191])},
#   'tau': {'mean': array([-3.25622927]), 'sigma': array([-2.08575138])}},
#  {'mu': {'mean': array([-0.07513188]), 'sigma': array([-1.97915393])},
#   'tau': {'mean': array([-3.25688233]), 'sigma': array([-2.0862024])}},
#  {'mu': {'mean': array([-0.07565621]), 'sigma': array([-1.97843792])},
#   'tau': {'mean': array([-3.25476657]), 'sigma': array([-2.08668351])}},
#  {'mu': {'mean': array([-0.07683981]), 'sigma': array([-1.97797649])},
#   'tau': {'mean': array([-3.25349643]), 'sigma': array([-2.0871221])}},
#  {'mu': {'mean': array([-0.0772548]), 'sigma': array([-1.97762789])},
#   'tau': {'mean': array([-3.25235574]), 'sigma': array([-2.08751048])}},
#  {'mu': {'mean': array([-0.07676643]), 'sigma': array([-1.97782211])},
#   'tau': {'mean': array([-3.25001396]), 'sigma': array([-2.08786613])}},
#  {'mu': {'mean': array([-0.07625332]), 'sigma': array([-1.97759408])},
#   'tau': {'mean': array([-3.24631687]), 'sigma': array([-2.08820126])}},
#  {'mu': {'mean': array([-0.07521138]), 'sigma': array([-1.97737723])},
#   'tau': {'mean': array([-3.2420295]), 'sigma': array([-2.0885013])}},
#  {'mu': {'mean': array([-0.07473377]), 'sigma': array([-1.97707934])},
#   'tau': {'mean': array([-3.23564053]), 'sigma': array([-2.08884073])}},
#  {'mu': {'mean': array([-0.07477196]), 'sigma': array([-1.97668525])},
#   'tau': {'mean': array([-3.22887336]), 'sigma': array([-2.08914788])}},
#  {'mu': {'mean': array([-0.07455151]), 'sigma': array([-1.9759731])},
#   'tau': {'mean': array([-3.2270082]), 'sigma': array([-2.08965719])}},
#  {'mu': {'mean': array([-0.07384037]), 'sigma': array([-1.97518205])},
#   'tau': {'mean': array([-3.22705944]), 'sigma': array([-2.09015565])}},
#  {'mu': {'mean': array([-0.07310036]), 'sigma': array([-1.97406831])},
#   'tau': {'mean': array([-3.22577515]), 'sigma': array([-2.09061717])}},
#  {'mu': {'mean': array([-0.07239147]), 'sigma': array([-1.9726544])},
#   'tau': {'mean': array([-3.22308492]), 'sigma': array([-2.0910533])}},
#  {'mu': {'mean': array([-0.07091381]), 'sigma': array([-1.97174346])},
#   'tau': {'mean': array([-3.22111258]), 'sigma': array([-2.09144349])}},
#  {'mu': {'mean': array([-0.07028327]), 'sigma': array([-1.97107109])},
#   'tau': {'mean': array([-3.21963437]), 'sigma': array([-2.09179014])}},
#  {'mu': {'mean': array([-0.0696379]), 'sigma': array([-1.97005976])},
#   'tau': {'mean': array([-3.21513828]), 'sigma': array([-2.09223688])}},
#  {'mu': {'mean': array([-0.06894071]), 'sigma': array([-1.96874823])},
#   'tau': {'mean': array([-3.21222883]), 'sigma': array([-2.09265165])}},
#  {'mu': {'mean': array([-0.06767167]), 'sigma': array([-1.96751514])},
#   'tau': {'mean': array([-3.21430568]), 'sigma': array([-2.09328786])}},
#  {'mu': {'mean': array([-0.0671484]), 'sigma': array([-1.96651957])},
#   'tau': {'mean': array([-3.21331699]), 'sigma': array([-2.09397137])}},
#  {'mu': {'mean': array([-0.06810523]), 'sigma': array([-1.96725254])},
#   'tau': {'mean': array([-3.21463603]), 'sigma': array([-2.09464339])}},
#  {'mu': {'mean': array([-0.06961127]), 'sigma': array([-1.96797265])},
#   'tau': {'mean': array([-3.21563558]), 'sigma': array([-2.09524213])}},
#  {'mu': {'mean': array([-0.07148352]), 'sigma': array([-1.96849666])},
#   'tau': {'mean': array([-3.21718178]), 'sigma': array([-2.09578127])}},
#  {'mu': {'mean': array([-0.07320779]), 'sigma': array([-1.96855339])},
#   'tau': {'mean': array([-3.21943398]), 'sigma': array([-2.09627165])}},
#  {'mu': {'mean': array([-0.07438023]), 'sigma': array([-1.96837203])},
#   'tau': {'mean': array([-3.21912032]), 'sigma': array([-2.09677945])}},
#  {'mu': {'mean': array([-0.0751414]), 'sigma': array([-1.9678758])},
#   'tau': {'mean': array([-3.21989124]), 'sigma': array([-2.09724718])}},
#  {'mu': {'mean': array([-0.07573301]), 'sigma': array([-1.96701744])},
#   'tau': {'mean': array([-3.21973823]), 'sigma': array([-2.09766897])}},
#  {'mu': {'mean': array([-0.07716694]), 'sigma': array([-1.96694908])},
#   'tau': {'mean': array([-3.2169129]), 'sigma': array([-2.09814104])}},
#  {'mu': {'mean': array([-0.07896842]), 'sigma': array([-1.96677888])},
#   'tau': {'mean': array([-3.21431563]), 'sigma': array([-2.09855922])}},
#  {'mu': {'mean': array([-0.08079936]), 'sigma': array([-1.96627336])},
#   'tau': {'mean': array([-3.20885102]), 'sigma': array([-2.0990672])}},
#  {'mu': {'mean': array([-0.08255952]), 'sigma': array([-1.96541828])},
#   'tau': {'mean': array([-3.2011652]), 'sigma': array([-2.09962695])}},
#  {'mu': {'mean': array([-0.08380255]), 'sigma': array([-1.96432969])},
#   'tau': {'mean': array([-3.19527254]), 'sigma': array([-2.10013672])}},
#  {'mu': {'mean': array([-0.08467962]), 'sigma': array([-1.96298294])},
#   'tau': {'mean': array([-3.18849457]), 'sigma': array([-2.10062239])}},
#  {'mu': {'mean': array([-0.08575232]), 'sigma': array([-1.96145003])},
#   'tau': {'mean': array([-3.18325926]), 'sigma': array([-2.10105926])}},
#  {'mu': {'mean': array([-0.08633422]), 'sigma': array([-1.95978493])},
#   'tau': {'mean': array([-3.17826776]), 'sigma': array([-2.10144812])}},
#  {'mu': {'mean': array([-0.08621175]), 'sigma': array([-1.95819654])},
#   'tau': {'mean': array([-3.17727958]), 'sigma': array([-2.10191796])}},
#  {'mu': {'mean': array([-0.0860364]), 'sigma': array([-1.95634078])},
#   'tau': {'mean': array([-3.17357541]), 'sigma': array([-2.10246577])}},
#  {'mu': {'mean': array([-0.08548624]), 'sigma': array([-1.95439017])},
#   'tau': {'mean': array([-3.16972974]), 'sigma': array([-2.10295928])}},
#  {'mu': {'mean': array([-0.08383374]), 'sigma': array([-1.9535091])},
#   'tau': {'mean': array([-3.16753598]), 'sigma': array([-2.10340637])}},
#  {'mu': {'mean': array([-0.08096152]), 'sigma': array([-1.95396677])},
#   'tau': {'mean': array([-3.16897291]), 'sigma': array([-2.10391092])}},
#  {'mu': {'mean': array([-0.07863688]), 'sigma': array([-1.95403684])},
#   'tau': {'mean': array([-3.17170743]), 'sigma': array([-2.10437278])}},
#  {'mu': {'mean': array([-0.0758192]), 'sigma': array([-1.95413212])},
#   'tau': {'mean': array([-3.17717249]), 'sigma': array([-2.10486766])}},
#  {'mu': {'mean': array([-0.07344696]), 'sigma': array([-1.95382277])},
#   'tau': {'mean': array([-3.18365855]), 'sigma': array([-2.10532699])}},
#  {'mu': {'mean': array([-0.0715347]), 'sigma': array([-1.95317222])},
#   'tau': {'mean': array([-3.19058742]), 'sigma': array([-2.10574312])}},
#  {'mu': {'mean': array([-0.06999798]), 'sigma': array([-1.95219477])},
#   'tau': {'mean': array([-3.19779254]), 'sigma': array([-2.10611919])}},
#  {'mu': {'mean': array([-0.06874125]), 'sigma': array([-1.95090172])},
#   'tau': {'mean': array([-3.20489629]), 'sigma': array([-2.10645435])}},
#  {'mu': {'mean': array([-0.06731163]), 'sigma': array([-1.94941365])},
#   'tau': {'mean': array([-3.20960433]), 'sigma': array([-2.10678901])}},
#  {'mu': {'mean': array([-0.06599229]), 'sigma': array([-1.9476424])},
#   'tau': {'mean': array([-3.2142203]), 'sigma': array([-2.10708525])}},
#  {'mu': {'mean': array([-0.06439845]), 'sigma': array([-1.94579297])},
#   'tau': {'mean': array([-3.21897359]), 'sigma': array([-2.10735023])}},
#  {'mu': {'mean': array([-0.06230504]), 'sigma': array([-1.94425342])},
#   'tau': {'mean': array([-3.22098461]), 'sigma': array([-2.10764795])}},
#  {'mu': {'mean': array([-0.06028885]), 'sigma': array([-1.94245844])},
#   'tau': {'mean': array([-3.22003442]), 'sigma': array([-2.10800771])}},
#  {'mu': {'mean': array([-0.05839793]), 'sigma': array([-1.94041549])},
#   'tau': {'mean': array([-3.22006711]), 'sigma': array([-2.10833704])}},
#  {'mu': {'mean': array([-0.05719571]), 'sigma': array([-1.93839929])},
#   'tau': {'mean': array([-3.21967872]), 'sigma': array([-2.10862752])}},
#  {'mu': {'mean': array([-0.05673379]), 'sigma': array([-1.9365141])},
#   'tau': {'mean': array([-3.22031944]), 'sigma': array([-2.10889677])}},
#  {'mu': {'mean': array([-0.05673465]), 'sigma': array([-1.93454734])},
#   'tau': {'mean': array([-3.22088614]), 'sigma': array([-2.10913192])}},
#  {'mu': {'mean': array([-0.05705211]), 'sigma': array([-1.93243773])},
#   'tau': {'mean': array([-3.22043627]), 'sigma': array([-2.10934568])}},
#  {'mu': {'mean': array([-0.05654108]), 'sigma': array([-1.93081731])},
#   'tau': {'mean': array([-3.22039212]), 'sigma': array([-2.10953344])}},
#  {'mu': {'mean': array([-0.05615719]), 'sigma': array([-1.92892241])},
#   'tau': {'mean': array([-3.21947459]), 'sigma': array([-2.10970268])}},
#  {'mu': {'mean': array([-0.05734335]), 'sigma': array([-1.92925658])},
#   'tau': {'mean': array([-3.21859755]), 'sigma': array([-2.10984766])}},
#  {'mu': {'mean': array([-0.05824522]), 'sigma': array([-1.92915927])},
#   'tau': {'mean': array([-3.2170724]), 'sigma': array([-2.10997596])}},
#  {'mu': {'mean': array([-0.05928475]), 'sigma': array([-1.92867505])},
#   'tau': {'mean': array([-3.21656527]), 'sigma': array([-2.11009539])}},
#  {'mu': {'mean': array([-0.06050751]), 'sigma': array([-1.92787355])},
#   'tau': {'mean': array([-3.21649205]), 'sigma': array([-2.11019815])}},
#  {'mu': {'mean': array([-0.06248366]), 'sigma': array([-1.92766116])},
#   'tau': {'mean': array([-3.21367613]), 'sigma': array([-2.1103835])}},
#  {'mu': {'mean': array([-0.0641995]), 'sigma': array([-1.92703625])},
#   'tau': {'mean': array([-3.20851564]), 'sigma': array([-2.11063359])}},
#  {'mu': {'mean': array([-0.06482532]), 'sigma': array([-1.92692236])},
#   'tau': {'mean': array([-3.20465516]), 'sigma': array([-2.11085917])}},
#  {'mu': {'mean': array([-0.06543548]), 'sigma': array([-1.92637912])},
#   'tau': {'mean': array([-3.20340526]), 'sigma': array([-2.11111353])}},
#  {'mu': {'mean': array([-0.06603706]), 'sigma': array([-1.92544871])},
#   'tau': {'mean': array([-3.20633801]), 'sigma': array([-2.11152137])}},
#  {'mu': {'mean': array([-0.06687261]), 'sigma': array([-1.92426268])},
#   'tau': {'mean': array([-3.20777947]), 'sigma': array([-2.11190035])}},
#  {'mu': {'mean': array([-0.06823468]), 'sigma': array([-1.92312568])},
#   'tau': {'mean': array([-3.20981439]), 'sigma': array([-2.11224105])}},
#  {'mu': {'mean': array([-0.06925308]), 'sigma': array([-1.92169896])},
#   'tau': {'mean': array([-3.21381683]), 'sigma': array([-2.11259812])}},
#  {'mu': {'mean': array([-0.06992374]), 'sigma': array([-1.92003558])},
#   'tau': {'mean': array([-3.21680866]), 'sigma': array([-2.1129162])}},
#  {'mu': {'mean': array([-0.0708469]), 'sigma': array([-1.9182146])},
#   'tau': {'mean': array([-3.21755593]), 'sigma': array([-2.11324166])}},
#  {'mu': {'mean': array([-0.07259631]), 'sigma': array([-1.9169524])},
#   'tau': {'mean': array([-3.21992659]), 'sigma': array([-2.11356539])}},
#  {'mu': {'mean': array([-0.07508988]), 'sigma': array([-1.91628993])},
#   'tau': {'mean': array([-3.22183664]), 'sigma': array([-2.11384957])}},
#  {'mu': {'mean': array([-0.07760126]), 'sigma': array([-1.91531732])},
#   'tau': {'mean': array([-3.22622138]), 'sigma': array([-2.11418992])}},
#  {'mu': {'mean': array([-0.08068731]), 'sigma': array([-1.91461969])},
#   'tau': {'mean': array([-3.23376601]), 'sigma': array([-2.11465138])}},
#  {'mu': {'mean': array([-0.08388764]), 'sigma': array([-1.91375489])},
#   'tau': {'mean': array([-3.24015431]), 'sigma': array([-2.11505931])}},
#  {'mu': {'mean': array([-0.08539713]), 'sigma': array([-1.91418155])},
#   'tau': {'mean': array([-3.24849906]), 'sigma': array([-2.11551445])}},
#  {'mu': {'mean': array([-0.08647505]), 'sigma': array([-1.91416142])},
#   'tau': {'mean': array([-3.26117573]), 'sigma': array([-2.11625694])}},
#  {'mu': {'mean': array([-0.08785656]), 'sigma': array([-1.9139137])},
#   'tau': {'mean': array([-3.27151463]), 'sigma': array([-2.11692082])}},
#  {'mu': {'mean': array([-0.08928452]), 'sigma': array([-1.9132875])},
#   'tau': {'mean': array([-3.28238332]), 'sigma': array([-2.11756183])}},
#  {'mu': {'mean': array([-0.09091949]), 'sigma': array([-1.91244791])},
#   'tau': {'mean': array([-3.29004781]), 'sigma': array([-2.11815713])}},
#  {'mu': {'mean': array([-0.09145948]), 'sigma': array([-1.91208014])},
#   'tau': {'mean': array([-3.29480589]), 'sigma': array([-2.11863818])}}]
